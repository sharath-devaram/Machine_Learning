# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [raw]
# What Are Stopwords?
# Stopwords are commonly used words in a language that carry little meaningful information on their own and are often removed from text during preprocessing. Examples of stopwords in English include "the," "is," "in," "and," "to," etc. These words are so frequent that they can overwhelm the important information in the text, especially in tasks like text classification, sentiment analysis, or topic modeling.
#
# Why Download Stopwords?
# The NLTK library includes a set of stopwords for various languages. Before you can use them in your code, you need to download the stopwords corpus. This is done using the nltk.download('stopwords') command.

# %%
data =pd.read_csv("IMDB Dataset.csv")
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# # Step 2: Data Preparation, Tokenization, Stopwords Removal and Stemming

# %% [raw]
# Our textual dataset needs preparation before being used for any problem based on NLP. Here we will:
#
# 1. remove links and all the special characters from the review column
# 2. tokenize and remove the stopwords from the review column
# 3. stem the words in the review column

# %%
import string
from nltk.corpus import stopwords

# %% [raw]
# Stemming is a text preprocessing technique used in natural language processing (NLP) to reduce words to their base or root form. The goal is to strip off prefixes, suffixes, and other affixes from a word to obtain the word's "stem." This process is helpful for simplifying text data, reducing the vocabulary size, and improving the efficiency of NLP models.
#
# Why Stemming is Useful:
# Reducing Vocabulary Size:
#
# Different forms of a word (e.g., "running," "runner," "ran") can be reduced to a single stem ("run"). This helps in reducing the number of unique words in the text, making it easier to analyze.
# Improving Model Performance:
#
# By consolidating different forms of a word, stemming can help models focus on the core meaning of the words, which can lead to better generalization and improved performance in tasks like text classification or information retrieval.
# Simplification:
#
# Stemming simplifies the text data by reducing words to their base form, making it easier to identify common themes or topics in a document.
# Stemming in NLTK:
# The NLTK library provides several stemming algorithms, with the most commonly used one being the Porter Stemmer. Another popular stemmer is the Lancaster Stemmer.
#
# Example of Stemming with NLTK:
# python
# Copy code
# import nltk
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize
#
# # Initialize the Porter Stemmer
# stemmer = PorterStemmer()
#
# # Example sentence
# sentence = "running runners ran easily quickly"
#
# # Tokenize the sentence into words
# words = word_tokenize(sentence)
#
# # Apply stemming
# stemmed_words = [stemmer.stem(word) for word in words]
#
# print(stemmed_words)
# Explanation:
# Importing Modules:
#
# PorterStemmer: The Porter stemming algorithm, which is widely used for stemming in English.
# word_tokenize: A function to split a sentence into individual words (tokens).
# Stemming Process:
#
# The sentence "running runners ran easily quickly" contains different forms of the words "run" and "quick."
# The Porter Stemmer reduces these words to their base forms: "run", "runner", "ran" become "run", and "easily" and "quickly" are reduced to "easili" and "quickli" respectively.
# Output:
#
# The stemmed words are: ['run', 'runner', 'ran', 'easili', 'quickli'].
# Types of Stemmers in NLTK:
# Porter Stemmer:
#
# A widely used stemming algorithm that is relatively fast and performs well in most cases.
# Example: "running" → "run"
# Lancaster Stemmer:
#
# A more aggressive stemmer compared to Porter, which can result in overly reduced stems.
# Example: "running" → "run"
# Snowball Stemmer:
#
# An improved version of the Porter Stemmer, also known as the Porter2 stemmer, that supports multiple languages.
# Example: "running" → "run"
# Limitations of Stemming:
# Over-stemming: Sometimes, the stemming process might be too aggressive, resulting in stems that are not actual words (e.g., "universities" → "univers").
# Under-stemming: Conversely, some words might not be reduced enough, leaving different forms of a word as separate stems (e.g., "running" → "run" but "runner" → "runner").
# Despite these limitations, stemming is a powerful tool for reducing text complexity and is often used in conjunction with other preprocessing techniques like tokenization and stopword removal.
#
# In summary, stemming in NLTK is used to reduce words to their root form, which helps in simplifying text data, reducing vocabulary size, and improving the performance of NLP models.

# %%
stemmer = nltk.SnowballStemmer("english")
stopword = set(stopwords.words("english"))

# %%
import re

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text=" ".join(text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\shara\AppData\Local\Temp\ipykernel_16740\3570870311.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]', '', text)
# C:\Users\shara\AppData\Local\Temp\ipykernel_16740\3570870311.py:4: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+', '', text)
# C:\Users\shara\AppData\Local\Temp\ipykernel_16740\3570870311.py:8: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*', '', text)

# %%
data["review"] = data["review"].apply(clean)

# %% [raw]
# Before moving forward, let’s have a quick look at the wordcloud of the review column:

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(i for i in data.review)
stopwords = set(STOPWORDS)

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [raw]
# Step 3: Text Vectorization
# The next step is text vectorization. It means to transform all the text tokens into numerical vectors. Here I will first perform text vectorization on the feature column (review column) and then split the data into training and test sets:

# %%
x = np.array(data["review"])
y = np.array(data["sentiment"])

cv = CountVectorizer()
X = cv.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=42)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 4723375 stored elements and shape (50000, 173746)>

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
model = PassiveAggressiveClassifier()
model.fit(X_train,y_train)
# Out:
# PassiveAggressiveClassifier()

# %%
user = input("Enter a Text: ")
data = cv.transform([user]).toarray()
output = model.predict(data)
print(output)
# Out:
# Enter a Text:  one of the worst movies I have ever seen!
# ['negative']
